# %%
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns
sns.set()

# %%
raw_data=pd.read_csv('line_chart_data.csv')
raw_data
# Out:
#             Date   GSPC500   FTSE100
# 0       1/3/2000  0.003264  0.000000
# 1       1/4/2000 -0.009549  0.000000
# 2       1/5/2000 -0.038345 -0.038137
# 3       1/6/2000  0.001922 -0.019502
# 4       1/7/2000  0.000956 -0.013571
# ...          ...       ...       ...
# 2865  12/27/2010 -0.002282  0.002135
# 2866  12/28/2010  0.003539  0.000000
# 2867  12/29/2010 -0.000254  0.000000
# 2868  12/30/2010  0.000524 -0.002080
# 2869  12/31/2010 -0.002128 -0.004236
#
# [2870 rows x 3 columns]

# %%
data=raw_data.copy(all)
data
# Out:
#             Date   GSPC500   FTSE100
# 0       1/3/2000  0.003264  0.000000
# 1       1/4/2000 -0.009549  0.000000
# 2       1/5/2000 -0.038345 -0.038137
# 3       1/6/2000  0.001922 -0.019502
# 4       1/7/2000  0.000956 -0.013571
# ...          ...       ...       ...
# 2865  12/27/2010 -0.002282  0.002135
# 2866  12/28/2010  0.003539  0.000000
# 2867  12/29/2010 -0.000254  0.000000
# 2868  12/30/2010  0.000524 -0.002080
# 2869  12/31/2010 -0.002128 -0.004236
#
# [2870 rows x 3 columns]

# %%
data['Date']=pd.to_datetime(data['Date'])
data
# Out:
#            Date   GSPC500   FTSE100
# 0    2000-01-03  0.003264  0.000000
# 1    2000-01-04 -0.009549  0.000000
# 2    2000-01-05 -0.038345 -0.038137
# 3    2000-01-06  0.001922 -0.019502
# 4    2000-01-07  0.000956 -0.013571
# ...         ...       ...       ...
# 2865 2010-12-27 -0.002282  0.002135
# 2866 2010-12-28  0.003539  0.000000
# 2867 2010-12-29 -0.000254  0.000000
# 2868 2010-12-30  0.000524 -0.002080
# 2869 2010-12-31 -0.002128 -0.004236
#
# [2870 rows x 3 columns]

# %%
plt.figure(figsize=(20,10))
labels=['GSPC500','FTSE100']
plt.plot(data['Date'],data['GSPC500'])
plt.plot(data['Date'],data['FTSE100'])
plt.xlabel("Year",fontsize=15)
plt.ylabel("Price",fontsize=15)
plt.title('GSPC500 and FTSE100 2008-2010')
plt.legend(labels)
sns.despine()
plt.show()
