# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %%
data=pd.read_csv('pie_chart_data.csv')
data
# Out:
#   Engine Fuel Type  Number of Cars
# 0           Diesel            2019
# 1              Gas             613
# 2            Other             154
# 3           Petrol            1559

# %%
raw_data=data.copy(all)

# %%
raw_data=raw_data.drop(raw_data[raw_data['Engine Fuel Type']=="Other"].index)

# %%
plt.figure(figsize=(10,6))
plt.pie(raw_data['Number of Cars'],labels=raw_data['Engine Fuel Type'])
plt.legend()
plt.title("Numbers of Cars")
plt.show()
