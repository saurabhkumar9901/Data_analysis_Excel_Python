# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
raw_data=pd.read_csv('scatter_plot_ii.csv')
raw_data
# Out:
#      Budget  Sales
# 0     337.1   22.1
# 1     128.9   10.4
# 2     132.4    9.3
# 3     251.3   18.5
# 4     250.0   12.9
# ..      ...    ...
# 195    55.7    7.6
# 196   107.2    9.7
# 197   192.7   12.8
# 198   391.8   25.5
# 199   249.4   13.4
#
# [200 rows x 2 columns]

# %%
data=raw_data.copy(all)
data
# Out:
#      Budget  Sales
# 0     337.1   22.1
# 1     128.9   10.4
# 2     132.4    9.3
# 3     251.3   18.5
# 4     250.0   12.9
# ..      ...    ...
# 195    55.7    7.6
# 196   107.2    9.7
# 197   192.7   12.8
# 198   391.8   25.5
# 199   249.4   13.4
#
# [200 rows x 2 columns]

# %%
sns.set(rc={'figure.figsize':(12,9)})
sns.regplot(x='Budget',y='Sales',data=data)
plt.title( 'Sales Vs Budget',fontsize=20,loc='left')
plt.xlabel('Budget', fontsize=20)
plt.ylabel('Sales', fontsize=20)
plt.show()
