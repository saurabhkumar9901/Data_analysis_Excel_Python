# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set()

# %%
data=pd.read_csv('stacked_area_chart_data.csv')
data
# Out:
#     Year    Gas  Petrol  Diesel  Other
# 0   1982      0      94       0      0
# 1   1983      0     347       0      0
# 2   1984    300       0     334      0
# 3   1985   1030    1184     984      0
# 4   1986    511     681    1066    340
# 5   1987   1817    1840     400    940
# 6   1988   2999    1882    2060      1
# 7   1989   2626    1641    1304    330
# 8   1990   1290    3247       1      0
# 9   1991   1566    6776    1063    400
# 10  1992   2358    1925    2824    350
# 11  1993   1231    3375    2302      0
# 12  1994   2386    5691    2569     77
# 13  1995   2373    5115    4563    666
# 14  1996   4264    6792    6996   1235
# 15  1997   7031    7336    7877    370
# 16  1998   5578    7511    8634    310
# 17  1999   4069    6147   16742   1493
# 18  2000   6459   10754   23102    531
# 19  2001   3932    7590   22115   1029
# 20  2002   3375    7069   18144    479
# 21  2003   6032    8518   19605    281
# 22  2004   8332    7978   17400   1821
# ...

# %%
raw_data=data.copy(all)
raw_data=raw_data.drop(['Other'],axis=1)
raw_data
# Out:
#     Year    Gas  Petrol  Diesel
# 0   1982      0      94       0
# 1   1983      0     347       0
# 2   1984    300       0     334
# 3   1985   1030    1184     984
# 4   1986    511     681    1066
# 5   1987   1817    1840     400
# 6   1988   2999    1882    2060
# 7   1989   2626    1641    1304
# 8   1990   1290    3247       1
# 9   1991   1566    6776    1063
# 10  1992   2358    1925    2824
# 11  1993   1231    3375    2302
# 12  1994   2386    5691    2569
# 13  1995   2373    5115    4563
# 14  1996   4264    6792    6996
# 15  1997   7031    7336    7877
# 16  1998   5578    7511    8634
# 17  1999   4069    6147   16742
# 18  2000   6459   10754   23102
# 19  2001   3932    7590   22115
# 20  2002   3375    7069   18144
# 21  2003   6032    8518   19605
# 22  2004   8332    7978   17400
# 23  2005   5785    7269   23551
# 24  2006   6439   12372   18024
# 25  2007  10902   21258   24683
# 26  2008  12876   22090   25471
# 27  2009   2179    5682   10191
# ...

# %%
plt.figure(figsize=(12,9))
plt.stackplot(raw_data['Year'],
              raw_data['Diesel'],
              raw_data['Gas'],
              raw_data['Petrol'],colors=['orange','red','blue'])
labels=['Gas','Petrol','Diseal']
plt.xlabel("Year")
plt.ylabel("Number of Cars")
plt.title('Year V/s Type of Vehicle')
plt.legend(labels)
plt.show()
